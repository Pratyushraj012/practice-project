# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv('titanic.csv')

# %%
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.DataFrame(data=ds)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.Survived.unique()
# Out:
# array([0, 1])

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Observation:- as we see above cabin has lots of missing values and also passengerid,name is of no use in buiding the model.Therefore we can remove these three columns.

# %%
df.drop(columns=['PassengerId','Name','Cabin'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %% [markdown]
# As we saw maximum passenger was in S so we replace null with S

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# Now we dont have any null in dataset

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019697    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.barplot(x='Sex',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# Mostly women are given preference while saving life so there percentage is very high.

# %%
sns.barplot(x='Embarked',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Survived'>

# %%
sns.barplot(x='Survived',y='Age',data=ds)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.countplot('Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot('Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot('Survived',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot('Survived',hue='Embarked',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# Insights-Embarked implies where the traveler mounted from. There are three possible values for Embark — Southampton, Cherbourg, and Queenstown. More than 70% of the people boarded from Southampton. Just under 20% boarded from Cherbourg and the rest boarded from Queenstown
#
# 2. Female survival rate is more than men.
#
# 3. I think embarked will help model to find relationship with target variable

# %%
sns.pairplot(data=df, hue='Pclass')
plt.show()

# %%
df['Family']=df['SibSp']+df['Parch']
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked  Family
# 0          S       1
# ...

# %%
duplicate=df[df.duplicated()]
duplicate
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch    Ticket     Fare  \
# 201         0       3    male  28.00      8      2  CA. 2343  69.5500
# 324         0       3    male  28.00      8      2  CA. 2343  69.5500
# 409         0       3  female  28.00      3      1      4133  25.4667
# 413         0       2    male  28.00      0      0    239853   0.0000
# 466         0       2    male  28.00      0      0    239853   0.0000
# 485         0       3  female  28.00      3      1      4133  25.4667
# 612         1       3  female  28.00      1      0    367230  15.5000
# 641         1       1  female  24.00      0      0  PC 17477  69.3000
# 644         1       3  female   0.75      2      1      2666  19.2583
# 692         1       3    male  28.00      0      0      1601  56.4958
# 709         1       3    male  28.00      1      1      2661  15.2458
# 792         0       3  female  28.00      8      2  CA. 2343  69.5500
# ...

# %%
df=df.drop_duplicates(keep='first')
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked  Family
# 0          S       1
# ...

# %% [markdown]
# Duplictes are identified and removed through ticket column.Now we can remove Sibsp,Parch,embarked,fare and ticket

# %%
df=df.drop(columns=['SibSp','Parch','Ticket','Fare','Embarked'],axis=1)
df
# Out:
#      Survived  Pclass     Sex   Age  Family
# 0           0       3    male  22.0       1
# 1           1       1  female  38.0       1
# 2           1       3  female  26.0       0
# 3           1       1  female  35.0       1
# 4           0       3    male  35.0       0
# ..        ...     ...     ...   ...     ...
# 886         0       2    male  27.0       0
# 887         1       1  female  19.0       0
# 888         0       3  female  28.0       3
# 889         1       1    male  26.0       0
# 890         0       3    male  32.0       0
#
# [875 rows x 5 columns]

# %%
sns.barplot(x='Family',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Survived'>

# %%
df['Sex']=df['Sex'].replace({'male':0,'female':1})

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  Family
# 0           0       3    0  22.0       1
# 1           1       1    1  38.0       1
# 2           1       3    1  26.0       0
# 3           1       1    1  35.0       1
# 4           0       3    0  35.0       0
# ..        ...     ...  ...   ...     ...
# 886         0       2    0  27.0       0
# 887         1       1    1  19.0       0
# 888         0       3    1  28.0       3
# 889         1       1    0  26.0       0
# 890         0       3    0  32.0       0
#
# [875 rows x 5 columns]

# %%
plt.figure(figsize=(8,12))
plotnumber=1
for column in df:
    if plotnumber <=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel=(df[column])
    plotnumber=plotnumber+1
plt.show()

# %%
plt.figure(figsize=(8,12))
plotnumber = 1

for column in df:
    if plotnumber <= 6:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel=(df[column])
        
    plotnumber = plotnumber+1
    
plt.show()

# %%
df.skew()
# Out:
# Survived    0.477835
# Pclass     -0.612333
# Sex         0.626098
# Age         0.509292
# Family      2.440022
# dtype: float64

# %%
from scipy.stats import zscore
df=df[np.abs(zscore(df)<3).all(axis=1)]
df
# Out:
#      Survived  Pclass  Sex   Age  Family
# 0           0       3    0  22.0       1
# 1           1       1    1  38.0       1
# 2           1       3    1  26.0       0
# 3           1       1    1  35.0       1
# 4           0       3    0  35.0       0
# ..        ...     ...  ...   ...     ...
# 886         0       2    0  27.0       0
# 887         1       1    1  19.0       0
# 888         0       3    1  28.0       3
# 889         1       1    0  26.0       0
# 890         0       3    0  32.0       0
#
# [848 rows x 5 columns]

# %%
plt.figure(figsize=(8,12))
plotnumber = 1

for column in df:
    if plotnumber <= 6:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel=(df[column])
        
    plotnumber = plotnumber+1
    
plt.show()

# %%
plt.figure(figsize=(8,12))
plotnumber = 1

for column in df:
    if plotnumber <= 6:
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel=(df[column])
        
    plotnumber = plotnumber+1
    
plt.show()

# %%
corr=df.corr()

# %%
plt.figure(figsize=(8,10))
sns.heatmap(corr,annot=True,annot_kws={'size':10})
plt.show()

# %% [markdown]
# # Standard Scaler

# %%
x=df.drop(['Survived'],axis=1)
y=df['Survived']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scale=scaler.fit_transform(x)

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=68)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (593, 4)
# (255, 4)
# (593,)
# (255,)

# %% [markdown]
# # Finding Best Random State

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
maxAccu=0
maxRs=0
for i in range(40,300):
    x_train,x_test,y_train,y_test=train_test_split(x_scale,y,test_size=0.25,random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(x_train,y_train)
    y_pred=log_reg.predict(x_test)
    acc=accuracy_score(y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print('best accuracy is:',maxAccu,'on Random_state:',maxRs)
# Out:
# best accuracy is: 0.8632075471698113 on Random_state: 119

# %% [markdown]
# # Logistics Regression

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scale,y,test_size=0.25,random_state=119)
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train)
y_pred=log_reg.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8632075471698113

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[121,  18],
#        [ 11,  62]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89       139
#            1       0.78      0.85      0.81        73
#
#     accuracy                           0.86       212
#    macro avg       0.85      0.86      0.85       212
# weighted avg       0.87      0.86      0.86       212

# %%
from sklearn.model_selection import cross_val_score
CVscore=cross_val_score(log_reg,x_scale,y,cv=5)
print(CVscore,'\n')
print(CVscore.mean(),'\n')
print(CVscore.std(),'\n')
# Out:
# [0.78823529 0.80588235 0.78235294 0.78698225 0.81065089]
#
# 0.7948207448659937
#
# 0.0112535230636284

# %% [markdown]
# # Decision Tree Classifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
y_pred=dtc.predict(x_test)
print('Decision Tree Classifier Evaluation')
print('\n')
print('Accuracy Score of Decision Tree Classifier :', accuracy_score(y_test, y_pred))
print('\n')
print('Confusion matrix of Decision Tree Classifier :',confusion_matrix(y_test, y_pred))
print('\n')
print('classification Report of Decision Tree Classifier',classification_report(y_test, y_pred))
# Out:
# Decision Tree Classifier Evaluation
#
#
# Accuracy Score of Decision Tree Classifier : 0.8018867924528302
#
#
# Confusion matrix of Decision Tree Classifier : [[111  28]
#  [ 14  59]]
#
#
# classification Report of Decision Tree Classifier               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84       139
#            1       0.68      0.81      0.74        73
#
#     accuracy                           0.80       212
#    macro avg       0.78      0.80      0.79       212
# weighted avg       0.82      0.80      0.81       212

# %%
from sklearn.model_selection import cross_val_score
cvscore=cross_val_score(dtc,x_scale,y,cv=5)
print('cross_val_score:',cvscore,'\n')
print('cross_val_score(mean):',cvscore.mean(),'\n')
print('cross_val_score(standard_deviation):',cvscore.std(),'\n')
# Out:
# cross_val_score: [0.8        0.80588235 0.81764706 0.80473373 0.82840237]
#
# cross_val_score(mean): 0.8113331012878525
#
# cross_val_score(standard_deviation): 0.010324024987370574

# %% [markdown]
# # Random Forest Classifier

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print('Random Forest Classifier')
print('\n')
print('Accuracy Score of Random Forest Classifier:', accuracy_score(y_test, y_pred))
print('\n')
print('Confusion matrix of Random Forest Classifier:','\n',confusion_matrix(y_test, y_pred))
print('\n')
print('classification Report of Random Forest Classifier','\n',classification_report(y_test, y_pred))
# Out:
# Random Forest Classifier
#
#
# Accuracy Score of Random Forest Classifier: 0.8160377358490566
#
#
# Confusion matrix of Random Forest Classifier:
#  [[115  24]
#  [ 15  58]]
#
#
# classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86       139
#            1       0.71      0.79      0.75        73
#
#     accuracy                           0.82       212
#    macro avg       0.80      0.81      0.80       212
# weighted avg       0.82      0.82      0.82       212

# %%
from sklearn.model_selection import cross_val_score
cvscore=cross_val_score(rfc,x_scale,y,cv=5)
print('Random_forest_cross val score')
print('\n')
print('cross_val_score',cvscore)
print('\n')
print('cross_val_score(mean):',cvscore.mean())
print('\n')
print('cross_val_score(Standard deviation):',cvscore.std())
print('\n')
# Out:
# Random_forest_cross val score
#
#
# cross_val_score [0.78823529 0.81764706 0.82941176 0.80473373 0.81656805]
#
#
# cross_val_score(mean): 0.8113191785589976
#
#
# cross_val_score(Standard deviation): 0.01393677328535435

# %% [markdown]
# # AdaBoost Classifier

# %%
adbc=AdaBoostClassifier()
adbc.fit(x_train,y_train)
y_pred=adbc.predict(x_test)
print('AdaBoost Classifier')
print('\n')
print('Accuracy Score of AdaBoost Classifier:', accuracy_score(y_test, y_pred))
print('\n')
print('Confusion matrix of AdaBoost Classifier:','\n',confusion_matrix(y_test, y_pred))
print('\n')
print('classification Report of AdaBoost Classifier','\n',classification_report(y_test, y_pred))
# Out:
# AdaBoost Classifier
#
#
# Accuracy Score of AdaBoost Classifier: 0.8490566037735849
#
#
# Confusion matrix of AdaBoost Classifier:
#  [[123  16]
#  [ 16  57]]
#
#
# classification Report of AdaBoost Classifier
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       139
#            1       0.78      0.78      0.78        73
#
#     accuracy                           0.85       212
#    macro avg       0.83      0.83      0.83       212
# weighted avg       0.85      0.85      0.85       212

# %%
from sklearn.model_selection import cross_val_score
cvscore=cross_val_score(adbc,x_scale,y,cv=5)
print('AdaBoostClassifier_cross val score')
print('\n')
print('cross_val_score',cvscore)
print('\n')
print('cross_val_score(mean):',cvscore.mean())
print('\n')
print('cross_val_score(Standard deviation):',cvscore.std())
print('\n')
# Out:
# AdaBoostClassifier_cross val score
#
#
# cross_val_score [0.80588235 0.78823529 0.81176471 0.81065089 0.84023669]
#
#
# cross_val_score(mean): 0.8113539853811348
#
#
# cross_val_score(Standard deviation): 0.016728933634570384

# %% [markdown]
# # Gradient Boosting Classifier

# %%
grad_bc=GradientBoostingClassifier()
grad_bc.fit(x_train,y_train)
y_pred=grad_bc.predict(x_test)
print('Gradient Boosting Classifier Results')
print('\n')
print('Accuracyscore:','\n',accuracy_score(y_test,y_pred))
print('\n')
print('Confusion_Matrix','\n',confusion_matrix(y_test,y_pred),)
print('\n')
print('Classification_report:','\n',classification_report(y_test,y_pred))
# Out:
# Gradient Boosting Classifier Results
#
#
# Accuracyscore:
#  0.8632075471698113
#
#
# Confusion_Matrix
#  [[125  14]
#  [ 15  58]]
#
#
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       139
#            1       0.81      0.79      0.80        73
#
#     accuracy                           0.86       212
#    macro avg       0.85      0.85      0.85       212
# weighted avg       0.86      0.86      0.86       212

# %%
from sklearn.model_selection import cross_val_score
cvscore=cross_val_score(grad_bc,x_scale,y,cv=5)
print('Gradient Boosting Classifier_cross val score')
print('\n')
print('cross_val_score',cvscore)
print('\n')
print('cross_val_score(mean):',cvscore.mean())
print('\n')
print('cross_val_score(Standard deviation):',cvscore.std())
print('\n')
# Out:
# Gradient Boosting Classifier_cross val score
#
#
# cross_val_score [0.81176471 0.81176471 0.82941176 0.81656805 0.84023669]
#
#
# cross_val_score(mean): 0.8219491820396799
#
#
# cross_val_score(Standard deviation): 0.01119398655811302

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = [{'fit_intercept': [True, False], #default: True
            'penalty': ['l1','l2'],
            'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], #default: lbfgs
            'random_state': [69]
             }]

# %%
GCV = GridSearchCV(LogisticRegression(),parameter,verbose=5)
GCV.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# ...

# %%
GCV.best_params_
# Out:
# {'fit_intercept': False,
#  'penalty': 'l1',
#  'random_state': 69,
#  'solver': 'liblinear'}

# %% [markdown]
# # Final Model

# %%
Final_mod = LogisticRegression(fit_intercept =False,penalty= "l1",solver='liblinear',random_state= 69)
Final_mod.fit(x_train,y_train)
y_pred=Final_mod.predict(x_test)
print('Final Random Forest Classifier Model')
print('Accuracy Score :','\n', accuracy_score(y_test, y_pred))
print('\n')
print('Confusion matrix of Random Forest Classifier :','\n',confusion_matrix(y_test, y_pred))
print('\n')
print('Classification Report of Random Forest Classifier','\n',classification_report(y_test, y_pred))
# Out:
# Final Random Forest Classifier Model
# Accuracy Score :
#  0.8537735849056604
#
#
# Confusion matrix of Random Forest Classifier :
#  [[116  23]
#  [  8  65]]
#
#
# Classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88       139
#            1       0.74      0.89      0.81        73
#
#     accuracy                           0.85       212
#    macro avg       0.84      0.86      0.84       212
# weighted avg       0.87      0.85      0.86       212

# %% [markdown]
# # Saving model

# %%
import joblib
joblib.dump(Final_mod,'Titanic_Survival_Project.pkl')
# Out:
# ['Titanic_Survival_Project.pkl']
